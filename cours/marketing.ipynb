# %% [markdown]
# https://towardsdatascience.com/exploratory-data-analysis-eda-python-87178e35b14

# %%
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns

# %%
path="C:/Users/bejao/Onedrive/data/Marketing_Analysis.csv"
data = pd.read_csv(path, skiprows=2, index_col='customerid')
data
# Out:
#              age  salary  balance   marital                  jobedu targeted  \
# customerid
# 1           58.0  100000     2143   married     management,tertiary      yes
# 2           44.0   60000       29    single    technician,secondary      yes
# 3           33.0  120000        2   married  entrepreneur,secondary      yes
# 4           47.0   20000     1506   married     blue-collar,unknown       no
# 5           33.0       0        1    single         unknown,unknown       no
# ...          ...     ...      ...       ...                     ...      ...
# 45207       51.0   60000      825   married     technician,tertiary      yes
# 45208       71.0   55000     1729  divorced         retired,primary      yes
# 45209       72.0   55000     5715   married       retired,secondary      yes
# 45210       57.0   20000      668   married   blue-collar,secondary      yes
# 45211       37.0  120000     2971   married  entrepreneur,secondary      yes
#
# ...

# %%
data.head(3)
data.tail(3)
# Out:
#              age  salary  balance  marital                  jobedu targeted  \
# customerid
# 45209       72.0   55000     5715  married       retired,secondary      yes
# 45210       57.0   20000      668  married   blue-collar,secondary      yes
# 45211       37.0  120000     2971  married  entrepreneur,secondary      yes
#
#            default housing loan    contact  day      month  \
# customerid
# 45209           no      no   no   cellular   17  nov, 2017
# 45210           no      no   no  telephone   17  nov, 2017
# 45211           no      no   no   cellular   17  nov, 2017
#
#                         duration  campaign  pdays  previous poutcome response
# customerid
# 45209       18.7833333333333 min         5    184         3  success      yes
# 45210       8.46666666666667 min         4     -1         0  unknown       no
# 45211       6.01666666666667 min         2    188        11    other       no

# %%
# data.jobedu
# data['jobedu']
# Out:
# customerid
# 1           management,tertiary
# 2          technician,secondary
# 3        entrepreneur,secondary
# 4           blue-collar,unknown
# 5               unknown,unknown
#                   ...
# 45207       technician,tertiary
# 45208           retired,primary
# 45209         retired,secondary
# 45210     blue-collar,secondary
# 45211    entrepreneur,secondary
# Name: jobedu, Length: 45211, dtype: object

# %%
#Extract job  & Education in newly from "jobedu" column.
# data['job']= data["jobedu"].apply(lambda x: x.split(",")[0])
# data['edu']= data["jobedu"].apply(lambda x: x.split(",")[1])

# Drop the "jobedu" column from the dataframe.
data.drop('jobedu', axis = 1, inplace = True)

# Printing the Dataset
data
# Out:
#              age  salary  balance   marital targeted default housing loan  \
# customerid
# 1           58.0  100000     2143   married      yes      no     yes   no
# 2           44.0   60000       29    single      yes      no     yes   no
# 3           33.0  120000        2   married      yes      no     yes  yes
# 4           47.0   20000     1506   married       no      no     yes   no
# 5           33.0       0        1    single       no      no      no   no
# ...          ...     ...      ...       ...      ...     ...     ...  ...
# 45207       51.0   60000      825   married      yes      no      no   no
# 45208       71.0   55000     1729  divorced      yes      no      no   no
# 45209       72.0   55000     5715   married      yes      no      no   no
# 45210       57.0   20000      668   married      yes      no      no   no
# 45211       37.0  120000     2971   married      yes      no      no   no
#
# ...

# %%
print(data.isnull().sum().index)
print(data.isnull().sum().values)
# type(data.isnull().sum()) #  Serie => Column
# Out:
# Index(['age', 'salary', 'balance', 'marital', 'targeted', 'default', 'housing',
#        'loan', 'contact', 'day', 'month', 'duration', 'campaign', 'pdays',
#        'previous', 'poutcome', 'response', 'job', 'edu'],
#       dtype='object')
# [20  0  0  0  0  0  0  0  0  0 50  0  0  0  0  0 30  0  0]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 45191 entries, 1 to 45211
# Data columns (total 19 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       45191 non-null  float64
#  1   salary    45191 non-null  int64
#  2   balance   45191 non-null  int64
#  3   marital   45191 non-null  object
#  4   targeted  45191 non-null  object
#  5   default   45191 non-null  object
#  6   housing   45191 non-null  object
#  7   loan      45191 non-null  object
#  8   contact   45191 non-null  object
#  9   day       45191 non-null  int64
#  10  month     45141 non-null  object
#  11  duration  45191 non-null  object
#  12  campaign  45191 non-null  int64
#  13  pdays     45191 non-null  int64
#  14  previous  45191 non-null  int64
#  15  poutcome  45191 non-null  object
#  16  response  45161 non-null  object
#  17  job       45191 non-null  object
#  18  edu       45191 non-null  object
# dtypes: float64(1), int64(6), object(12)
# ...

# %%
# data[~data.age.isnull()]

# data[~data.age.isnull()]

# Dropping the records with age missing in data dataframe.
# data = data[~data.age.isnull()]#.copy()

# Checking the missing values in the dataset.
data.isnull().sum()
# data
# Out:
# age          0
# salary       0
# balance      0
# marital      0
# targeted     0
# default      0
# housing      0
# loan         0
# contact      0
# day          0
# month       50
# duration     0
# campaign     0
# pdays        0
# previous     0
# poutcome     0
# response    30
# job          0
# edu          0
# dtype: int64

# %%
# Réaliser un résumé de la col
# print(data.month.value_counts(normalize=True))
# data.month.value_counts(normalize=True).plot.barh()
month_mode=data.month.mode()[0]
# Fill the missing values with mode value of month in data.
# data.month.fillna(month_mode, inplace=True)

# Let's see the null values in the month column.
data.isnull().sum()
# Out:
# age          0
# salary       0
# balance      0
# marital      0
# targeted     0
# default      0
# housing      0
# loan         0
# contact      0
# day          0
# month        0
# duration     0
# campaign     0
# pdays        0
# previous     0
# poutcome     0
# response    30
# job          0
# edu          0
# dtype: int64

# %%
# Dropping the records with response missing in the dataframe.
# data = data[~data.response.isnull()]#.copy()

# Checking the missing values in the dataset.
# data.isnull().sum()
data
# Out:
#              age  salary  balance   marital targeted default housing loan  \
# customerid
# 1           58.0  100000     2143   married      yes      no     yes   no
# 2           44.0   60000       29    single      yes      no     yes   no
# 3           33.0  120000        2   married      yes      no     yes  yes
# 4           47.0   20000     1506   married       no      no     yes   no
# 5           33.0       0        1    single       no      no      no   no
# ...          ...     ...      ...       ...      ...     ...     ...  ...
# 45207       51.0   60000      825   married      yes      no      no   no
# 45208       71.0   55000     1729  divorced      yes      no      no   no
# 45209       72.0   55000     5715   married      yes      no      no   no
# 45210       57.0   20000      668   married      yes      no      no   no
# 45211       37.0  120000     2971   married      yes      no      no   no
#
# ...

# %%
# Recherche d'outliers sur les col numériques
# data.salary.value_counts()
data.salary.describe()
# Out:
# count     45161.000000
# mean      57004.849317
# std       32087.698810
# min           0.000000
# 25%       20000.000000
# 50%       60000.000000
# 75%       70000.000000
# max      120000.000000
# Name: salary, dtype: float64

# %%
data.sort_values(by='salary', ascending=True).head()
# Out:
#              age  salary  balance  marital targeted default housing loan  \
# customerid
# 39571       54.0       0     1157  married      yes      no      no   no
# 23159       31.0       0      526  married      yes      no      no   no
# 8829        30.0       0    13052   single      yes      no      no   no
# 11096       46.0       0       10   single      yes      no      no   no
# 17740       45.0       0     4413  married       no      no      no   no
#
#               contact  day      month              duration  campaign  pdays  \
# customerid
# 39571        cellular   26  may, 2017  1.63333333333333 min         2     -1
# 23159        cellular   26  aug, 2017  2.16666666666667 min        13     -1
# 8829          unknown    4  jun, 2017               140 sec         1     -1
# 11096         unknown   18  jun, 2017                64 sec         6     -1
# 17740       telephone   29  jul, 2017  1.28333333333333 min        35     -1
#
# ...

# %%
# data.salary.plot.box()
# data.boxplot()
# Out:
# <AxesSubplot:>

# %%
data.balance.plot.box()
# Out:
# <AxesSubplot:>

# %%
# data.mean()
# data.salary.mean()
# data.salary.median()
# data.salary.var()
# data.salary.std()
# Out:
# 32087.69881005341

# %%
# Décrire une col de type Categorical
# Recherche d'Outlier, value_counts(), ...

# Let's calculate the percentage of each job status category.
# data.job.value_counts(normalize=True).reset_index()

#plot the bar graph of percentage job categories
data.job.value_counts(normalize=True).plot.barh()
# Out:
# <AxesSubplot:>

# %%
data.edu.value_counts(normalize=True).plot.pie()
# Out:
# <AxesSubplot:ylabel='edu'>

# %%
# Analyse bivariée
# plt.scatter(data.salary, data.balance)
data.plot.scatter(x="age", y="balance")
# Out:
# <AxesSubplot:xlabel='age', ylabel='balance'>

# %%
#plot the pair plot of salary, balance and age in data dataframe.
sns.pairplot(data=data, vars=['salary','balance','age'])

# %%
# Creating a matrix using age, salry, balance as rows and columns
# data_corr = data[['age','salary','balance']] .corr()
print(data_corr)
#plot the correlation matrix of salary, balance and age in data dataframe.
sns.heatmap(data_corr, annot=True, cmap = 'Reds', center=0)
# Out:
#               age    salary   balance
# age      1.000000  0.024513  0.097710
# salary   0.024513  1.000000  0.055489
# balance  0.097710  0.055489  1.000000
# <AxesSubplot:>

# %%
# Bivariée : Numéric -  Categorical
# data.response.value_counts()
# data.groupby('response')['salary'].mean()
# data.groupby('response')['balance'].mean()
# data.groupby('response')['age'].mean()
data.groupby('response')['balance'].describe()
# Out:
#             count         mean          std     min     25%    50%     75%  \
# response
# no        39876.0  1304.292281  2975.358156 -8019.0   58.75  417.0  1345.0
# yes        5285.0  1804.681362  3502.216259 -3058.0  210.00  733.0  2159.0
#
#                max
# response
# no        102127.0
# yes        81204.0

# %%
sns.boxplot(data.response, data.balance)
# Out:
# C:\Users\bejao\miniconda3\lib\site-packages\seaborn\_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# <AxesSubplot:xlabel='response', ylabel='balance'>

# %%
# Bivariée Categorical - Categorical
# data.response
# data.marital.value_counts()
# data.groupby('marital')['response'].size().reset_index() #.plot.bar()
# La ligne 4 n'est pas très pertinente
data.groupby(['response', 'marital']).count()['edu'].plot.barh()
# Out:
# <AxesSubplot:ylabel='response,marital'>

# %%
pd.crosstab(data.response, data.marital, margins=True, normalize=True) * 100
# Out:
# marital    divorced    married     single         All
# response
# no        10.134851  54.099776  24.062798   88.297425
# yes        1.375080   6.095968   4.231527   11.702575
# All       11.509931  60.195744  28.294325  100.000000
